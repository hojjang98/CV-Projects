# %% [markdown]
# Install Dependencies

# %%
#!pip install yt-dlp fastdtw mediapipe opencv-python-headless --quiet

# %%
#if not working well...
#!pip uninstall -y numpy
#!pip install numpy==1.23.5
#!pip install --upgrade mediapipe

# %% [markdown]
# Download and Trim Videos

# %%
# Download reference and user videos from YouTube
# !yt-dlp -f bestvideo+bestaudio --merge-output-format mp4 "https://www.youtube.com/watch?v=a72NCO0OFXA" -o "dance.mp4"
# !yt-dlp -f bestvideo+bestaudio --merge-output-format mp4 "https://www.youtube.com/watch?v=wxEmSmDQEuU" -o "user.mp4"

# Trim the videos to the desired start time (keep everything after that point)
# !ffmpeg -ss 00:00:09 -i "dance.mp4" -c copy "dance_trimmed.mp4"
# !ffmpeg -ss 00:00:11 -i "user.mp4" -c copy "user_trimmed.mp4"
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=a72NCO0OFXA
# [youtube] a72NCO0OFXA: Downloading webpage
# [youtube] a72NCO0OFXA: Downloading tv client config
# [youtube] a72NCO0OFXA: Downloading tv player API JSON
# [youtube] a72NCO0OFXA: Downloading ios player API JSON
# [youtube] a72NCO0OFXA: Downloading m3u8 information
# [info] a72NCO0OFXA: Downloading 1 format(s): 397+251
# [download] dance.mp4 has already been downloaded
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wxEmSmDQEuU
# [youtube] wxEmSmDQEuU: Downloading webpage
# [youtube] wxEmSmDQEuU: Downloading tv client config
# [youtube] wxEmSmDQEuU: Downloading tv player API JSON
# [youtube] wxEmSmDQEuU: Downloading ios player API JSON
# [youtube] wxEmSmDQEuU: Downloading m3u8 information
# [info] wxEmSmDQEuU: Downloading 1 format(s): 397+251
# [download] user.mp4 has already been downloaded
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [libdav1d @ 0x59557becff80] libdav1d 0.9.2
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'dance.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:04:48.00, start: 0.000000, bitrate: 413 kb/s
#   Stream #0:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 640x480 [SAR 1:1 DAR 4:3], 265 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: opus (Opus / 0x7375704F), 48000 Hz, stereo, fltp, 141 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File 'dance_trimmed.mp4' already exists. Overwrite? [y/N] y
# [mp4 @ 0x59557bf11f00] track 1: codec frame size is not set
# Output #0, mp4, to 'dance_trimmed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 640x480 [SAR 1:1 DAR 4:3], q=2-31, 265 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: opus (Opus / 0x7375704F), 48000 Hz, stereo, fltp, 141 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame= 8507 fps=0.0 q=-1.0 Lsize=   14433kB time=00:04:38.98 bitrate= 423.8kbits/s speed=1.2e+03x
# video:9298kB audio:4912kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.568574%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [libdav1d @ 0x5c89eb00ef80] libdav1d 0.9.2
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'user.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:05:01.70, start: 0.000000, bitrate: 831 kb/s
#   Stream #0:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 854x480 [SAR 1:1 DAR 427:240], 691 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: opus (Opus / 0x7375704F), 48000 Hz, stereo, fltp, 133 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File 'user_trimmed.mp4' already exists. Overwrite? [y/N] y
# [mp4 @ 0x5c89eb015980] track 1: codec frame size is not set
# Output #0, mp4, to 'user_trimmed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomav01iso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: av1 (Main) (av01 / 0x31307661), yuv420p(tv, bt709), 854x480 [SAR 1:1 DAR 427:240], q=2-31, 691 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 30k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: opus (Opus / 0x7375704F), 48000 Hz, stereo, fltp, 133 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame= 8741 fps=0.0 q=-1.0 Lsize=   30145kB time=00:04:50.68 bitrate= 849.5kbits/s speed=1.77e+03x
# video:25157kB audio:4759kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.765299%

# %% [markdown]
# Extract Frames

# %%
import os

def extract_frames_with_ffmpeg(video_path, output_dir, fps=2):
    os.makedirs(output_dir, exist_ok=True)
    # This command extracts 2 frames per second from the video
    cmd = f"ffmpeg -i \"{video_path}\" -vf fps={fps} \"{output_dir}/frame_%04d.jpg\" -hide_banner -loglevel error"
    os.system(cmd)

# Extract frames from the trimmed videos
extract_frames_with_ffmpeg("dance_trimmed.mp4", "frames_ref", fps=2)
extract_frames_with_ffmpeg("user_trimmed.mp4", "frames_user", fps=2)

# %% [markdown]
# Extract Poses from Frames

# %%
import mediapipe as mp
import numpy as np
import cv2
from tqdm import tqdm

# Use MediaPipe's Pose module
mp_pose = mp.solutions.pose

def extract_pose_from_images(image_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    with mp_pose.Pose(static_image_mode=True) as pose:
        for fname in tqdm(sorted(os.listdir(image_dir))):
            if not fname.endswith(".jpg"):
                continue  # Skip non-image files

            img_path = os.path.join(image_dir, fname)
            image_bgr = cv2.imread(img_path)
            if image_bgr is None:
                continue  # Skip if the image failed to load

            image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
            results = pose.process(image_rgb)

            # If pose landmarks are found, save them as .npy
            if results.pose_landmarks:
                keypoints = [(lm.x, lm.y) for lm in results.pose_landmarks.landmark]
                keypoints = np.array(keypoints)
                np.save(os.path.join(output_dir, fname.replace(".jpg", ".npy")), keypoints)

# Run pose extraction on both reference and user frames
extract_pose_from_images("frames_ref", "pose_data/gukmin")
extract_pose_from_images("frames_user", "pose_data/user_trial_01")
# Out:
# 100%|██████████| 560/560 [00:26<00:00, 21.20it/s]
# 100%|██████████| 583/583 [00:28<00:00, 20.61it/s]

# %% [markdown]
# Load Pose Sequences

# %%
def load_pose_sequence(npy_dir):
    # Load all .npy files in order and return as a list of pose frames
    files = sorted(f for f in os.listdir(npy_dir) if f.endswith(".npy"))
    return np.array([np.load(os.path.join(npy_dir, f)) for f in files])

# Load reference and user pose sequences
ref_seq = load_pose_sequence("pose_data/gukmin")
usr_seq = load_pose_sequence("pose_data/user_trial_01")

# %% [markdown]
# Automatic DTW Shift Alignment

# %%
from fastdtw import fastdtw
from scipy.spatial.distance import cosine, euclidean

# Compute DTW distance between two pose sequences
def compute_dtw_distance(seq1, seq2):
    s1 = seq1.reshape(seq1.shape[0], -1)  # Flatten frames
    s2 = seq2.reshape(seq2.shape[0], -1)
    distance, _ = fastdtw(s1, s2, dist=euclidean)
    return distance

# Try different starting offsets to find best time alignment
def find_best_shift(ref_seq, usr_seq, max_shift=10):
    best_shift = 0
    best_distance = float("inf")
    best_aligned = None

    for shift in range(-max_shift, max_shift + 1):
        # Shift user sequence and trim both sequences to same length
        if shift >= 0:
            usr_cut = usr_seq[shift:]
            ref_cut = ref_seq[:len(usr_cut)]
        else:
            usr_cut = usr_seq[:shift]
            ref_cut = ref_seq[-shift:]

        min_len = min(len(ref_cut), len(usr_cut))
        if min_len == 0:
            continue

        # Compute DTW distance for this alignment
        distance = compute_dtw_distance(ref_cut[:min_len], usr_cut[:min_len])

        # Keep best (lowest) distance and aligned sequence
        if distance < best_distance:
            best_distance = distance
            best_shift = shift
            best_aligned = usr_cut[:min_len]

    return best_shift, best_distance, best_aligned

# Run the shift finder
shift, dtw_distance, aligned_usr = find_best_shift(ref_seq, usr_seq)

# %% [markdown]
# Cosine Similarity

# %%
def frame_cosine_similarity(p1, p2):
    # Compare two pose frames (flattened) using cosine similarity
    return 1 - cosine(p1.flatten(), p2.flatten())

# Align both sequences to the same length
min_len = min(len(ref_seq), len(aligned_usr))
ref_seq = ref_seq[:min_len]
aligned_usr = aligned_usr[:min_len]

# Compute similarity for each frame pair
cosine_scores = [frame_cosine_similarity(ref_seq[i], aligned_usr[i]) for i in range(min_len)]

# %% [markdown]
# Plot

# %%
import matplotlib.pyplot as plt

plt.plot(cosine_scores)
plt.title("Frame-wise Cosine Similarity")
plt.xlabel("Frame")
plt.ylabel("Similarity")
plt.grid()
plt.show()

# %% [markdown]
# DTW Path

# %%
# Flatten pose sequences for DTW
ref_flat = ref_seq.reshape(ref_seq.shape[0], -1)
usr_flat = aligned_usr.reshape(aligned_usr.shape[0], -1)

# Get the DTW matching path between frames
_, path = fastdtw(ref_flat, usr_flat, dist=euclidean)

# Visualize frame-to-frame alignment
plt.plot([i for i, _ in path], [j for _, j in path], '.-')
plt.title("DTW Alignment Path")
plt.xlabel("Reference Frame")
plt.ylabel("User Frame")
plt.grid()
plt.show()

# %% [markdown]
# Score Summary (dtw_max = 2000)

# %%
def score_summary(cosine_scores, dtw_distance, dtw_max=2000):
    # Calculate average cosine similarity as a % score
    frame_score = np.mean(cosine_scores) * 100

    # DTW score: lower distance means higher score
    dtw_score = max(0, 100 * (1 - dtw_distance / dtw_max))

    # Combine both for final evaluation
    total_score = 0.5 * frame_score + 0.5 * dtw_score

    return {
        "Frame Avg. Score": round(frame_score, 2),
        "DTW Score": round(dtw_score, 2),
        "Total Score": round(total_score, 2)
    }

# Print results
summary = score_summary(cosine_scores, dtw_distance)
print("Shift:", shift)
print("DTW Distance:", round(dtw_distance, 2))
print(summary)
# Out:
# Shift: -10
# DTW Distance: 527.77
# {'Frame Avg. Score': 95.59, 'DTW Score': 73.61, 'Total Score': 84.6}

# %% [markdown]
# Feedback from Score

# %%
def feedback_from_score(total_score):
    if total_score >= 85:
        return "🌟 Excellent! Your movement is highly synchronized."
    elif total_score >= 70:
        return "👍 Good job! A few parts need adjustment."
    elif total_score >= 50:
        return "⚠️ Some noticeable mismatches exist. Keep practicing!"
    else:
        return "❗ Significant mismatch. Try matching the rhythm and motion more closely."

# 💬 Feedback 출력
print("💬 Feedback:", feedback_from_score(summary["Total Score"]))
# Out:
# 💬 Feedback: 👍 Good job! A few parts need adjustment.

# %% [markdown]
# Download pose_data for streamlit

# %%
# !zip -r pose_data.zip pose_data/
# Out:
#   adding: pose_data/ (stored 0%)
#   adding: pose_data/gukmin/ (stored 0%)
#   adding: pose_data/gukmin/frame_0242.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0215.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0243.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0142.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0138.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0355.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0364.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0183.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0365.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0523.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0468.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0042.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0423.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0377.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0305.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0070.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0071.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0269.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0476.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0006.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0208.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0272.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0465.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0081.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0088.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0315.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0106.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0507.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0151.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0334.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0012.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0036.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0075.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0096.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0474.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0494.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0182.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0033.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0492.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0328.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0225.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0461.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0108.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0428.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0509.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0383.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0068.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0399.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0111.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0140.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0359.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0144.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0351.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0230.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0105.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0131.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0117.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0381.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0388.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0371.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0266.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0155.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0410.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0198.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0292.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0214.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0504.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0402.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0197.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0127.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0367.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0152.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0224.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0157.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0043.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0101.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0361.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0072.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0090.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0331.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0297.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0282.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0295.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0149.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0160.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0229.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0380.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0095.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0143.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0014.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0223.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0241.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0041.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0044.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0254.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0032.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0114.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0107.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0287.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0338.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0314.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0411.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0469.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0059.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0236.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0503.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0457.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0063.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0168.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0175.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0204.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0253.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0162.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0413.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0122.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0028.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0459.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0227.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0524.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0159.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0024.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0179.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0283.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0270.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0133.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0274.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0520.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0299.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0192.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0163.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0233.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0031.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0268.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0045.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0069.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0498.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0035.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0391.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0062.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0161.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0156.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0216.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0039.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0201.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0196.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0169.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0400.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0066.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0463.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0396.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0008.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0237.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0093.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0370.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0220.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0128.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0091.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0135.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0055.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0085.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0303.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0221.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0084.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0306.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0087.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0360.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0277.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0026.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0470.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0340.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0317.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0518.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0124.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0519.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0076.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0232.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0104.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0265.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0137.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0145.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0279.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0207.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0526.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0316.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0112.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0099.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0082.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0326.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0385.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0136.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0150.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0185.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0247.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0125.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0389.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0130.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0132.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0199.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0329.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0102.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0471.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0285.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0209.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0362.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0134.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0376.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0497.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0513.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0020.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0238.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0239.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0074.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0318.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0200.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0289.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0213.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0126.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0378.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0064.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0323.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0337.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0038.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0167.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0427.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0333.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0110.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0321.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0369.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0407.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0195.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0278.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0455.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0194.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0203.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0226.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0123.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0530.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0408.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0153.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0320.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0353.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0267.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0098.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0404.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0210.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0454.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0358.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0058.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0386.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0293.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0129.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0245.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0120.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0301.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0499.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0304.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0384.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0173.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0235.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0281.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0336.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0148.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0171.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0467.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0147.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0170.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0528.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0013.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0527.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0366.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0011.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0387.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0034.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0113.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0166.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0246.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0022.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0089.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0405.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0488.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0252.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0456.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0339.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0426.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0298.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0174.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0472.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0508.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0495.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0525.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0193.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0392.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0211.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0517.npy (deflated 43%)
#   adding: pose_data/gukmin/frame_0406.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0286.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0529.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0146.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0491.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0357.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0116.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0397.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0023.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0493.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0462.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0206.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0009.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0424.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0249.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0296.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0010.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0393.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0073.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0458.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0094.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0029.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0100.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0531.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0352.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0332.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0027.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0231.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0394.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0374.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0401.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0021.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0356.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0335.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0512.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0015.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0017.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0115.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0005.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0097.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0466.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0244.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0379.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0164.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0294.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0103.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0273.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0030.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0205.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0478.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0291.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0172.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0121.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0460.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0078.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0415.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0228.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0176.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0271.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0390.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0154.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0251.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0420.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0473.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0217.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0165.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0177.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0119.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0354.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0280.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0409.npy (deflated 38%)
#   adding: pose_data/gukmin/frame_0079.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0475.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0522.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0464.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0016.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0490.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0141.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0025.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0496.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0363.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0302.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0118.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0004.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0403.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0516.npy (deflated 42%)
#   adding: pose_data/gukmin/frame_0489.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0219.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0181.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0240.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0421.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0018.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0077.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0092.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0007.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0184.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0234.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0480.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0086.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0158.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0422.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0532.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0515.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0275.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0067.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0037.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0019.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0382.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0222.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0202.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0322.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0425.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0395.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0061.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0479.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0080.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0040.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0521.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0212.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0083.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0248.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0375.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0398.npy (deflated 39%)
#   adding: pose_data/gukmin/frame_0139.npy (deflated 40%)
#   adding: pose_data/gukmin/frame_0330.npy (deflated 41%)
#   adding: pose_data/gukmin/frame_0319.npy (deflated 40%)
#   adding: pose_data/user_trial_01/ (stored 0%)
#   adding: pose_data/user_trial_01/frame_0242.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0215.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0243.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0218.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0446.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0355.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0364.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0365.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0523.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0468.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0042.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0564.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0423.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0377.npy (deflated 43%)
#   adding: pose_data/user_trial_01/frame_0186.npy (deflated 43%)
#   adding: pose_data/user_trial_01/frame_0071.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0259.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0264.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0006.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0272.npy (deflated 44%)
#   adding: pose_data/user_trial_01/frame_0465.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0081.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0088.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0315.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0560.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0507.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0151.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0334.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0012.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0036.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0075.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0096.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0474.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0494.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0033.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0492.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0328.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0461.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0509.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0449.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0383.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0250.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0399.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0514.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0140.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0144.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0558.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0230.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0506.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0561.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0131.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0505.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0117.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0381.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0541.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0388.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0262.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0419.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0371.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0155.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0439.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0481.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0567.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0571.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0410.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0198.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0180.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0214.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0504.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0127.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0367.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0224.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0101.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0361.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0072.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0090.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0331.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0282.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0548.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0547.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0095.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0143.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0014.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0241.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0429.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0041.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0557.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0254.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0114.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0412.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0338.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0314.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0544.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0411.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0059.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0236.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0503.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0168.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0187.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0204.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0540.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0253.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0162.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0413.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0122.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0459.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0569.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0227.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0524.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0159.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0024.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0486.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0179.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0283.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0270.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0133.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0060.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0274.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0520.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0299.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0192.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0163.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0233.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0031.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0268.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0045.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0498.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0035.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0391.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0573.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0501.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0161.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0156.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0343.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0216.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0039.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0543.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0552.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0324.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0400.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0463.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0008.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0237.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0261.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0093.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0535.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0445.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0370.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0220.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0313.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0128.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0091.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0341.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0135.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0085.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0221.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0307.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0487.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0310.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0562.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0087.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0256.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0001.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0109.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0360.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0277.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0340.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0434.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0260.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0124.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0076.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0104.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0265.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0207.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0526.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0316.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0099.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0082.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0136.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0150.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0046.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0372.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0125.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0389.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0130.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0536.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0132.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0199.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0329.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0102.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0362.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0134.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0497.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0513.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0020.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0537.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0368.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0238.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0239.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0436.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0074.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0318.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0200.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0289.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0451.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0450.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0545.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0213.npy (deflated 38%)
#   adding: pose_data/user_trial_01/frame_0126.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0052.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0378.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0064.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0337.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0502.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0453.npy (deflated 38%)
#   adding: pose_data/user_trial_01/frame_0167.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0427.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0333.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0263.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0416.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0321.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0276.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0369.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0407.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0195.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0455.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0194.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0554.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0203.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0226.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0123.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0530.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0408.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0153.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0353.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0267.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0438.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0098.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0404.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0572.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0210.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0454.npy (deflated 38%)
#   adding: pose_data/user_trial_01/frame_0358.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0373.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0568.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0255.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0129.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0245.npy (deflated 38%)
#   adding: pose_data/user_trial_01/frame_0120.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0301.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0499.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0384.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0235.npy (deflated 38%)
#   adding: pose_data/user_trial_01/frame_0336.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0467.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0147.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0534.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0528.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0013.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0527.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0011.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0034.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0441.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0166.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0246.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0022.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0089.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0405.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0252.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0339.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0174.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0472.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0508.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0437.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0495.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0525.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0193.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0444.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0325.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0211.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0309.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0517.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0406.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0286.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0529.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0146.npy (deflated 43%)
#   adding: pose_data/user_trial_01/frame_0491.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0257.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0357.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0397.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0023.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0550.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0284.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0493.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0206.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0249.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0010.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0073.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0458.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0094.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0029.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0100.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0531.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0332.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0027.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0394.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0401.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0559.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0356.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0335.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0512.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0017.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0005.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0097.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0244.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0379.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0500.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0273.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0030.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0478.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0342.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0172.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0121.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0460.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0078.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0417.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0288.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0154.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0251.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0420.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0510.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0542.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0217.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0570.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0440.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0165.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0177.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0119.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0354.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0280.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0409.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0079.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0522.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0464.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0016.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0490.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0141.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0025.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0442.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0496.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0363.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0302.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0118.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0549.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0447.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0551.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0004.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0489.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0555.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0565.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0219.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0240.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0421.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0018.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0539.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0258.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0189.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0092.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0556.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0007.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0184.npy (deflated 42%)
#   adding: pose_data/user_trial_01/frame_0086.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0158.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0532.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0275.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0037.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0019.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0382.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0563.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0222.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0533.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0202.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0322.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0566.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0483.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0080.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0040.npy (deflated 39%)
#   adding: pose_data/user_trial_01/frame_0002.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0521.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0212.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0546.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0083.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0248.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0047.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0375.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0048.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0398.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0188.npy (deflated 40%)
#   adding: pose_data/user_trial_01/frame_0330.npy (deflated 41%)
#   adding: pose_data/user_trial_01/frame_0319.npy (deflated 41%)
